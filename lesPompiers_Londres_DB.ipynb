# %%
import numpy as np
import pandas as pd
Incident=pd.read_csv('/home/lva/Bureau/dataScientest/projet_pompiers_Londres/data/LFB Incident data Last 3 years.csv')
# Out:
# /home/lva/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
Incident.shape[0]
# Out:
# 1580629

# %%
Mobilisation=pd.read_csv("/home/lva/Bureau/dataScientest/projet_pompiers_Londres/data/Mobilisation.csv")

# %%
Mobilisation.shape[0]
# Out:
# 576892

# %%
merged_df=pd.merge(Mobilisation, Incident, how='inner')

# %%
merged_df.shape[0]
# Out:
# 558180

# %%
corr_matrix = merged_df.corr().abs()
corr_matrix
# Out:
#                                    Unnamed: 0   CalYear  HourOfCall  \
# Unnamed: 0                           1.000000  0.958739    0.009131
# CalYear                              0.958739  1.000000    0.009070
# HourOfCall                           0.009131  0.009070    1.000000
# ResourceMobilisationId               0.999900  0.957610    0.008969
# TurnoutTimeSeconds                   0.016578  0.012015    0.221057
# TravelTimeSeconds                    0.051033  0.041160    0.041514
# AttendanceTimeSeconds                0.045027  0.036647    0.018094
# DateAndTimeReturned                       NaN       NaN         NaN
# PumpOrder                            0.010427  0.009399    0.010976
# DelayCodeId                          0.041148  0.038434    0.028446
# UPRN                                 0.022227  0.021053    0.011680
# USRN                                 0.003187  0.003102    0.015321
# Easting_m                            0.003119  0.002546    0.015769
# ...

# %%
merged_df.isna().sum()
# Out:
# Unnamed: 0                                     0
# IncidentNumber                                 0
# CalYear                                        0
# HourOfCall                                     0
# ResourceMobilisationId                         0
# Resource_Code                                  0
# PerformanceReporting                           0
# DateAndTimeMobilised                           0
# DateAndTimeMobile                           2339
# DateAndTimeArrived                             0
# TurnoutTimeSeconds                          2351
# TravelTimeSeconds                           2355
# AttendanceTimeSeconds                          0
# DateAndTimeLeft                              234
# DateAndTimeReturned                       558180
# DeployedFromStation_Code                       8
# DeployedFromStation_Name                       8
# DeployedFromLocation                         401
# PumpOrder                                      0
# ...
