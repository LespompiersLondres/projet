# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn import svm
from sklearn import ensemble
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestRegressor

merged_df=pd.read_csv("/home/user/Bureau/dataScientest/projet_pompiers_Londres/data/merged_meteo.csv")

# %%
merged_df.head()
# Out:
#        date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0  20200101          8.0       0.0              13.0       6.6        4.1
# 1  20200101          8.0       0.0              13.0       6.6        4.1
# 2  20200101          8.0       0.0              13.0       6.6        4.1
# 3  20200101          8.0       0.0              13.0       6.6        4.1
# 4  20200101          8.0       0.0              13.0       6.6        4.1
#
#    min_temp  precipitation  pressure  snow_depth  ...  \
# 0       1.7            0.0  102980.0         NaN  ...
# 1       1.7            0.0  102980.0         NaN  ...
# 2       1.7            0.0  102980.0         NaN  ...
# 3       1.7            0.0  102980.0         NaN  ...
# 4       1.7            0.0  102980.0         NaN  ...
#
#   FirstPumpArriving_AttendanceTime  FirstPumpArriving_DeployedFromStation  \
# 0                            324.0                             Hillingdon
# 1                            324.0                             Hillingdon
# 2                            195.0                               Richmond
# 3                            426.0                               Edmonton
# 4                            249.0                                Tooting
#
#    SecondPumpArriving_AttendanceTime SecondPumpArriving_DeployedFromStation  \
# 0                              292.0                             Hillingdon
# 1                              292.0                             Hillingdon
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                              255.0                                Tooting
#
#    NumStationsWithPumpsAttending  NumPumpsAttending  PumpCount  \
# 0                            1.0                2.0          2
# 1                            1.0                2.0          2
# 2                            1.0                1.0          1
# 3                            1.0                1.0          1
# 4                            1.0                2.0          2
#
#   PumpMinutesRounded Notional Cost (£) NumCalls
# 0               60.0             339.0      3.0
# 1               60.0             339.0      3.0
# 2               60.0             339.0      1.0
# 3               60.0             339.0      1.0
# 4               63.0             356.0      2.0
#
# [5 rows x 71 columns]

# %%
df=merged_df[['cloud_cover', 'sunshine', 'mean_temp', 'precipitation', 'CalYear', 'HourOfCall', 'AttendanceTimeSeconds']]
df=df.dropna()
df.head()
# Out:
#    cloud_cover  sunshine  mean_temp  precipitation  CalYear  HourOfCall  \
# 0          8.0       0.0        4.1            0.0     2020           0
# 1          8.0       0.0        4.1            0.0     2020           0
# 2          8.0       0.0        4.1            0.0     2020           0
# 3          8.0       0.0        4.1            0.0     2020           0
# 4          8.0       0.0        4.1            0.0     2020           0
#
#    AttendanceTimeSeconds
# 0                    324
# 1                    292
# 2                    195
# 3                    426
# 4                    249

# %%
target=df['AttendanceTimeSeconds'] #à essayer avec Traveltime
df_train=df[['cloud_cover', 'sunshine', 'mean_temp', 'precipitation', 'CalYear', 'HourOfCall']]



X_train, X_test, y_train, y_test = train_test_split(df_train, target, test_size=0.2)

# %%
score_knn=[]



for k in range(2, 41):
	knn=neighbors.KNeighborsRegressor(n_neighbors=k)
	knn.fit(X_train, y_train)
	score_knn.append(knn.score(X_test, y_test))
	

y_knn = knn.predict(X_test)


knn_score = knn.score(X_train, y_train)
print("KNeighborsRegressor score:", knn_score)
# Out:
# KNeighborsRegressor score: 0.06193427413204966

# %%
# Diviser la cible en quartiles (4 quartiles)
quartiles = pd.qcut(target, q=4, labels=False)

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(df_train, quartiles, test_size=0.2)

score_knn=[]



for k in range(2, 41):
	knn=neighbors.KNeighborsRegressor(n_neighbors=k)
	knn.fit(X_train, y_train)
	score_knn.append(knn.score(X_test, y_test))
	

y_knn = knn.predict(X_test)


knn_score = knn.score(X_train, y_train)
print("KNeighborsRegressor score with quartiles:", knn_score)
# Out:
# KNeighborsRegressor score with quartiles: 0.05802241479761272
